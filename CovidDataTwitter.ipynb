# %%
import os
import tweepy as tw
import pandas as pd
from tqdm import tqdm, notebook

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

# %%
# %run ./Keys.ipynb

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "#covid19 -filter:retweets"
date_since = "2020-03-01"
# Collect tweets
tweets = tw.Cursor(api.search_tweets, q=search_words,lang="en", since=date_since).items(12452)

# %%
tweets_copy = []
for tweet in tqdm(tweets):
     tweets_copy.append(tweet)
# Out:
# 0it [00:00, ?it/s]Unexpected parameter: since
# 1it [00:00,  1.09it/s]Unexpected parameter: since
# 16it [00:01, 11.06it/s]Unexpected parameter: since
# 31it [00:02, 12.98it/s]Unexpected parameter: since
# 46it [00:03, 15.80it/s]Unexpected parameter: since
# 61it [00:04, 15.53it/s]Unexpected parameter: since
# 74it [00:05, 15.57it/s]Unexpected parameter: since
# 89it [00:06, 16.00it/s]Unexpected parameter: since
# 104it [00:06, 16.33it/s]Unexpected parameter: since
# 119it [00:07, 16.77it/s]Unexpected parameter: since
# 134it [00:08, 17.67it/s]Unexpected parameter: since
# 149it [00:09, 18.39it/s]Unexpected parameter: since
# 164it [00:10, 17.04it/s]Unexpected parameter: since
# 179it [00:11, 18.13it/s]Unexpected parameter: since
# 194it [00:11, 18.71it/s]Unexpected parameter: since
# 209it [00:12, 18.99it/s]Unexpected parameter: since
# 224it [00:13, 20.18it/s]Unexpected parameter: since
# 239it [00:14, 18.37it/s]Unexpected parameter: since
# 254it [00:15, 17.90it/s]Unexpected parameter: since
# 269it [00:15, 18.31it/s]Unexpected parameter: since
# 284it [00:17, 16.21it/s]Unexpected parameter: since
# 299it [00:17, 16.57it/s]Unexpected parameter: since
# 314it [00:18, 18.37it/s]Unexpected parameter: since
# 329it [00:19, 20.01it/s]Unexpected parameter: since
# 344it [00:19, 19.90it/s]Unexpected parameter: since
# 359it [00:20, 18.53it/s]Unexpected parameter: since
# 373it [00:20, 17.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 tweets_copy = []
# ----> 2 for tweet in tqdm(tweets):
#       3      tweets_copy.append(tweet)
#
# File ~\anaconda3\lib\site-packages\tqdm\std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~\anaconda3\lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~\anaconda3\lib\site-packages\tweepy\cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~\anaconda3\lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~\anaconda3\lib\site-packages\tweepy\cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File ~\anaconda3\lib\site-packages\tweepy\api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tweepy\api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tweepy\api.py:1303, in API.search_tweets(self, q, **kwargs)
#    1209 @pagination(mode='id')
#    1210 @payload('search_results')
#    1211 def search_tweets(self, q, **kwargs):
#    1212     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1213                      until, since_id, max_id, include_entities)
#    1214
#    (...)
#    1301     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1302     """
# -> 1303     return self.request(
#    1304         'GET', 'search/tweets', endpoint_parameters=(
#    1305             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1306             'until', 'since_id', 'max_id', 'include_entities'
#    1307         ), q=q, **kwargs
#    1308     )
#
# File ~\anaconda3\lib\site-packages\tweepy\api.py:216, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     214 # Execute request
#     215 try:
# --> 216     resp = self.session.request(
#     217         method, url, params=params, headers=headers,
#     218         data=post_data, files=files, json=json_payload,
#     219         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220     )
#     221 except Exception as e:
#     222     raise TweepyException(f'Failed to send request: {e}').with_traceback(sys.exc_info()[2])
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1038 # Force connect early to allow us to validate the connection.
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#    1043     warnings.warn(
#    1044         (
#    1045             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1050         InsecureRequestWarning,
#    1051     )
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
print(f"new tweets retrieved: {len(tweets_copy)}")
# Out:
# new tweets retrieved: 373

# %%
tweets_df = pd.DataFrame()
for tweet in tqdm(tweets_copy):
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_created': tweet.user.created_at,
                                               'user_followers': tweet.user.followers_count,
                                               'user_friends': tweet.user.friends_count,
                                               'user_favourites': tweet.user.favourites_count,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source,
                                               'is_retweet': tweet.retweeted}, index=[0]))
# Out:
#   0%|          | 0/373 [00:00<?, ?it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   0%|          | 1/373 [00:00<06:08,  1.01it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   1%|          | 2/373 [00:01<05:37,  1.10it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   1%|          | 3/373 [00:02<04:46,  1.29it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   1%|          | 4/373 [00:03<05:46,  1.06it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   1%|▏         | 5/373 [00:04<06:28,  1.06s/it]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   2%|▏         | 6/373 [00:05<05:53,  1.04it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   2%|▏         | 7/373 [00:06<05:14,  1.16it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   2%|▏         | 8/373 [00:07<05:07,  1.19it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   2%|▏         | 9/373 [00:08<05:51,  1.04it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   3%|▎         | 10/373 [00:09<05:37,  1.08it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   3%|▎         | 11/373 [00:09<05:01,  1.20it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   3%|▎         | 12/373 [00:10<05:00,  1.20it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   3%|▎         | 13/373 [00:11<04:54,  1.22it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   4%|▍         | 14/373 [00:12<04:44,  1.26it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   4%|▍         | 15/373 [00:13<05:01,  1.19it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   4%|▍         | 16/373 [00:14<05:09,  1.15it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   5%|▍         | 17/373 [00:14<05:09,  1.15it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   5%|▍         | 18/373 [00:15<04:53,  1.21it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   5%|▌         | 19/373 [00:16<04:41,  1.26it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   5%|▌         | 20/373 [00:17<04:33,  1.29it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   6%|▌         | 21/373 [00:18<05:30,  1.07it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   6%|▌         | 22/373 [00:19<05:34,  1.05it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   6%|▌         | 23/373 [00:20<05:06,  1.14it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   6%|▋         | 24/373 [00:21<05:11,  1.12it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   7%|▋         | 25/373 [00:22<05:39,  1.02it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   7%|▋         | 26/373 [00:23<05:30,  1.05it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   7%|▋         | 27/373 [00:23<04:58,  1.16it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   8%|▊         | 28/373 [00:24<04:53,  1.18it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   8%|▊         | 29/373 [00:25<05:08,  1.12it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
#   8%|▊         | 30/373 [00:26<05:15,  1.09it/s]C:\Users\ozlem\AppData\Local\Temp\ipykernel_18492\978419686.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
# 100%|██████████| 373/373 [05:31<00:00,  1.13it/s]

# %%
tweets_df.head()
# Out:
#           user_name        user_location  \
# 0        GIP.UNIOVI  43.364375,-5.838212
# 0  BW Businessworld            New Delhi
# 0        Wirepoints          Chicago, IL
# 0      ABS-CBN News  Manila, Philippines
# 0   TheAllINeed.com
#
#                                                                                                                                                 user_description  \
# 0                                                                                         Grupo de Investigación Psicosocial: ARPANET-BITNET (activo desde 1988)
# 0  BW Businessworld is India’s largest & most respected business magazine known for its independent opinions | https://t.co/u7FlZNZx4Y | https://t.co/sRn19SIBLn
# 0                             Independent research, commentary and news aggregation. We connect the dots between Illinois government, economy and people. #twill
# 0                                                                  Stories, video, and multimedia for Filipinos worldwide, from ABS-CBN News and Current Affairs
# 0                                                                                                                              This website is The All I Need. 😀
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0 2011-08-20 08:16:40+00:00             579           877             1933
# 0 2009-05-01 05:57:27+00:00           21469           435             5266
# 0 2012-11-02 22:32:56+00:00            5412          1000             9843
# 0 2008-08-16 10:09:33+00:00         8769229          1063             1299
# 0 2011-05-24 04:34:49+00:00            4158             1              736
#
#    user_verified                      date  \
# 0          False 2022-10-18 11:56:25+00:00
# 0          False 2022-10-18 11:56:13+00:00
# 0          False 2022-10-18 11:55:41+00:00
# 0           True 2022-10-18 11:55:00+00:00
# 0          False 2022-10-18 11:54:58+00:00
#
#                                                                                                                                                                                                                                                                                                                 text  \
# 0                                                                                                                                                Association Between Time Interval from #COVID19 #Vaccination\nto In Vitro #Fertilization and #Pregnancy Rate After Fresh Embryo Transfer📃🏥\nhttps://t.co/aYmsiH5IB2
# 0                                                                                                                                                      Threat In India From New Covid Variant Of BF.7 Called '#OmicronSpawn'\n\nRead: https://t.co/HPoUrUe7oK\n\n#covid #covid19 #omicron #covidnews #omicronvariant
# 0  If Illinois is any better off financially for now, it’s because of the near-$200B in federal #COVID19 bailout money it got. Even then, Illinois' credit rating is still at the bottom of the barrel nationally. Via @Wirepoints\n\nhttps://t.co/O3kFlztXH6 #twill #muniland @MoodysInvSvc https://t.co/O4X9Rfeu99
# 0                                                                                                                                                                                                                                            DOH reports 1,196 new #COVID19 cases, 34 deaths https://t.co/I3WDwGHh2C
# 0                                                                                                                                                        #Qatar World Cup spy apps\n#COVID19 #Ehteraz #GPS #Hayya #Privacy #SpyApps #Spyware #TrackingApp #WorldCup\nhttps://t.co/AbF2LYfy2o https://t.co/nBucPOrHMc
#
#                                                                                   hashtags  \
# 0                                         [COVID19, Vaccination, Fertilization, Pregnancy]
# 0                                                                    [OmicronSpawn, covid]
# 0                                                                                [COVID19]
# 0                                                                                [COVID19]
# 0  [Qatar, COVID19, Ehteraz, GPS, Hayya, Privacy, SpyApps, Spyware, TrackingApp, WorldCup]
#
#              source  is_retweet
# 0  Twitter for iPad       False
# 0   Twitter Web App       False
# 0   Twitter Web App       False
# 0         TweetDeck       False
# 0       TheAllINeed       False

# %%
tweets_df.to_csv('covid19_tweets.csv')

# %%
tweets_df.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')
